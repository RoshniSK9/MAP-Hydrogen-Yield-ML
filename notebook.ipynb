# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd()

# Sanity check
if not (PROJECT_ROOT / "H2_pred_ML_models").exists():
    raise FileNotFoundError(
        f"'H2_pred_ML_models' not found in {PROJECT_ROOT}"
    )

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Using PROJECT_ROOT:", PROJECT_ROOT)
print("sys.path[0]:", sys.path[0])

# --- Autoreload ---
# %load_ext autoreload
# %autoreload 2

# --- Import + verify ---
import H2_pred_ML_models
from H2_pred_ML_models.run import run_all
import H2_pred_ML_models.run as _run

print("H2_pred_ML_models imported from:", H2_pred_ML_models.__file__)
print("run imported from:", _run.__file__)

results = run_all(
    file_path="Dataset_Modelling.xlsx",
    target_col="H2 yield (mmol/g of feedstock)",
    categorical_cols=["Catalyst (-)", "Microwave absorber (-)"],
    test_size=0.20,
    random_state=30,
    k=10,
    n_iter_search=50,
    n_jobs_model=2,
    n_jobs_search=1,
    zoom_max=80,
    out_root="results_H2_pred_ML_models",
)

results
# Out:
# Using PROJECT_ROOT: /Users/roshnisajivkumar/Documents/pca-project
# sys.path[0]: /Users/roshnisajivkumar/Documents/pca-project
# H2_pred_ML_models imported from: /Users/roshnisajivkumar/Documents/pca-project/H2_pred_ML_models/__init__.py
# run imported from: /Users/roshnisajivkumar/Documents/pca-project/H2_pred_ML_models/run.py
# Output directory: /Users/roshnisajivkumar/Documents/pca-project/results_H2_pred_ML_models/run_20260921_151101
# Dataset: 241 samples, 23 numeric base cols, 2 categorical cols
# Train: 192 samples | Test: 49 samples
# Train set saved: results_H2_pred_ML_models/run_20260921_151101/train_set.csv
# Test set saved:  results_H2_pred_ML_models/run_20260921_151101/test_set.csv
#
# === BASELINE (predict TRAIN mean) ===
# TRAIN: RMSE=18.8095, R2=0.0000
# TEST : RMSE=21.8896, R2=-0.0222
# BASELINE TEST R2 SD (boot): 0.0470
#
#
# ==================== XGBoost ====================
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# CV best R2 (validation folds): 0.6960
# TRAIN: RMSE=6.3903, R2=0.8846
# TEST : RMSE=12.0066, R2=0.6925
# TEST  R2 95% CI: [0.4698, 0.8151]
#   Feature importance CSV saved: results_H2_pred_ML_models/run_20260921_151101/xgb_feature_importance_XGBoost.csv
#   Feature importance plot saved: results_H2_pred_ML_models/run_20260921_151101/xgb_feature_importance_gain_XGBoost.png
#   Comparison plot saved: results_H2_pred_ML_models/run_20260921_151101/shap_vs_xgb_importance_XGBoost.png
#   Feature importance complete for XGBoost.
#
#
# ==================== RandomForest ====================
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# CV best R2 (validation folds): 0.6795
# TRAIN: RMSE=7.1238, R2=0.8566
# TEST : RMSE=12.5007, R2=0.6666
# TEST  R2 95% CI: [0.4079, 0.8095]
#
#
# ==================== HGBR ====================
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# CV best R2 (validation folds): 0.6855
# TRAIN: RMSE=7.9061, R2=0.8233
# TEST : RMSE=13.0020, R2=0.6394
# TEST  R2 95% CI: [0.4002, 0.7749]
#
#
# ==================== Ridge ====================
# Fitting 10 folds for each of 7 candidates, totalling 70 fits
# /Users/roshnisajivkumar/miniconda3/envs/pca_project/lib/python3.12/site-packages/sklearn/model_selection/_search.py:317: UserWarning: The total space of parameters 7 is smaller than n_iter=50. Running 7 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# CV best R2 (validation folds): 0.6657
# TRAIN: RMSE=8.7516, R2=0.7835
# TEST : RMSE=14.3872, R2=0.5584
# TEST  R2 95% CI: [0.3416, 0.6989]
# /Users/roshnisajivkumar/miniconda3/envs/pca_project/lib/python3.12/site-packages/shap/explainers/_linear.py:99: FutureWarning: The feature_perturbation option is now deprecated in favor of using the appropriate masker (maskers.Independent, maskers.Partition or maskers.Impute).
#   warnings.warn(wmsg, FutureWarning)
# ==================== PCA+LR ====================
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# /Users/roshnisajivkumar/miniconda3/envs/pca_project/lib/python3.12/site-packages/sklearn/model_selection/_search.py:317: UserWarning: The total space of parameters 6 is smaller than n_iter=50. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# CV best R2 (validation folds): 0.6522
# TRAIN: RMSE=9.1391, R2=0.7639
# TEST : RMSE=14.3179, R2=0.5627
# TEST  R2 95% CI: [0.3264, 0.7128]
#
#
# ==================== SVR ====================
# Fitting 10 folds for each of 32 candidates, totalling 320 fits
# /Users/roshnisajivkumar/miniconda3/envs/pca_project/lib/python3.12/site-packages/sklearn/model_selection/_search.py:317: UserWarning: The total space of parameters 32 is smaller than n_iter=50. Running 32 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# CV best R2 (validation folds): 0.6582
# TRAIN: RMSE=9.0816, R2=0.7669
# TEST : RMSE=15.5263, R2=0.4857
# TEST  R2 95% CI: [0.2113, 0.6674]
#   [SHAP-SVR] KernelExplainer: 49 test rows, 50 background rows ...
#   0%|          | 0/49 [00:00<?, ?it/s]
# ============================================================
# ALL MODELS COMPLETE
# ============================================================
#        model  train_r2  test_r2
#      XGBoost  0.884577 0.692464
# RandomForest  0.856562 0.666632
#         HGBR  0.823329 0.639356
#       PCA+LR  0.763923 0.562662
#        Ridge  0.783516 0.558418
#          SVR  0.766886 0.485727
#
# Saved summary: /Users/roshnisajivkumar/Documents/pca-project/results_H2_pred_ML_models/run_20260921_151101/summary_results_run_20260921_151101.csv
# Run directory:  /Users/roshnisajivkumar/Documents/pca-project/results_H2_pred_ML_models/run_20260921_151101
#           model  cv_best_r2  train_rmse  train_r2  test_rmse   test_r2  \
# 0       XGBoost    0.695965    6.390339  0.884577  12.006575  0.692464
# 1  RandomForest    0.679457    7.123762  0.856562  12.500660  0.666632
# 2          HGBR    0.685506    7.906061  0.823329  13.002015  0.639356
# 3        PCA+LR    0.652169    9.139112  0.763923  14.317905  0.562662
# 4         Ridge    0.665726    8.751648  0.783516  14.387216  0.558418
# 5           SVR    0.658222    9.081571  0.766886  15.526301  0.485727
#
#    test_r2_ci95_low  test_r2_ci95_high  \
# 0          0.469836           0.815100
# 1          0.407892           0.809483
# 2          0.400228           0.774891
# 3          0.326375           0.712820
# 4          0.341578           0.698919
# 5          0.211344           0.667410
#
#                                          best_params
# 0  {'model__subsample': 0.8, 'model__reg_lambda':...
# 1  {'model__n_estimators': 1200, 'model__min_samp...
# 2  {'model__min_samples_leaf': 10, 'model__max_le...
# 3                          {'pca__n_components': 30}
# 4                              {'model__alpha': 1.0}
# 5  {'model__kernel': 'rbf', 'model__gamma': 'scal...
